# %%
#Import Libraries
import numpy as np #Faster Data processing (arrays)
import pandas as pd #EDA Purpose

# %%
# !pip install numpy pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: numpy in C:\Users\asus\AppData\Roaming\Python\Python314\site-packages (2.5.1)
# Requirement already satisfied: pandas in C:\Users\asus\AppData\Roaming\Python\Python314\site-packages (3.0.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\asus\AppData\Roaming\Python\Python314\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\asus\AppData\Roaming\Python\Python314\site-packages (from pandas) (2026.3)
# Requirement already satisfied: six>=1.5 in C:\Users\asus\AppData\Roaming\Python\Python314\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\asus\Desktop

# %%
import os

print(os.listdir())
# Out:
# ['.ipynb_checkpoints', '1-1 Supple', '1.docx', '147_cclab_week3.pdf', '2-2 Semester', '3-1 Semester', 'Advance Java Programming Week - 1 [173].docx', 'Advanced Java Programming Lab - 1 Observation.docx', 'ANU 7.0', 'Anu Script Manager.lnk', 'April-01-2024 to May-31-2025 PhonePe_Transaction_Statement.pdf', 'AUDIO.mpeg', 'College', 'DAD files', 'DBMS', 'desktop.ini', 'Discord.lnk', 'DMS', 'Docker Desktop.lnk', 'Drishti-Form-Project', 'epics', 'Firefox.exe', 'G O MS NO 34.pdf', 'GitHub.lnk', 'GoogleInputToolsTelugu.exe', 'JDBC', 'JDBCLab', 'Jun-30-2023 to june 2026 PhonePe_Transaction_Statement.pdf', 'Meeting 16.07.2026-1.pdf', 'Microsoft Edge.lnk', 'New Microsoft Word Document (2).docx', 'New Microsoft Word Document.docx', 'Policy No._20260617_133725_0000.pdf', 'preprocessed_zoo.csv', 'preprocessed_zoo.csv.metadata', 'shutdown.lnk', 'SU-24 VRSEC ACADEMIC CALENDER AY 2025-2026.jpg', 'SU24 IT 4th sem syllabus[1].pdf', 'SU_2026_AIML', 'swayam.txt', 'Timetable III Table.pdf', 'TRUST-DOC', 'Visual Studio Code.lnk', 'WORKSHOP.ipynb']

# %%
#Understanding the data --->info(),describe(),columns(),unique(),value_counts:
data.info() #Complete information of the dataset

# %%
#reading columns
data.columns

# %%
#We will seperate the columns
data.dtypes;
data.select_dtypes(include='object') #object columns
data.select_dtypes(include = ['int','float'])

# %%
#Total number of passengers in the ship
print('Total number of passengers in the ship are',len(data))

# %%
#Statistical Distribution --->describe()
data.describe() #default ---> numerical columns only

# %%
data.describe(include='object')
#top returns most occuring value
#freq returns the count of the most occuring value

# %%
#We try to understand the unique values in the columns
data['Sex'].unique()

# %%
data['Embarked'].unique() #Embarked is place of travel

# %%
data['Cabin'].unique();
data['Pclass'].unique()

# %%
data['Survived'].unique()

# %%
data['SibSp'].unique()

# %%
data['Parch'].unique()

# %%
#Count of each unique value
data['Sex'].value_counts()

# %%
data['Survived'].value_counts()

# %%
data['Pclass'].value_counts();
data['Pclass'].value_counts(ascending=True)

# %%
data['Embarked'].value_counts()

# %%
data['Age'].value_counts().head(30) #head() it returns top samples by default\
#it is 5

# %%
#to get any random samples in the dataset
data.sample(15)

# %%
#DataVisualization --> matplotlib,seaborn,plotly
import matplotlib.pyplot as plt #!pip install matplotlib

# %%
#Distribution of Age
plt.hist(data['Age'],bins=15,color='blue')
plt.xlabel("Age")
plt.ylabel("Count")
plt.title("Age Distribution")
plt.show()

# %%
#Display the count of the bars in histogram
#Distribution of Age
counts,edges,bars = plt.hist(data['Age'],bins=25,color='red')
print(counts)
print(bars)
plt.xlabel("Age")
plt.ylabel("Count")
plt.bar_label(bars)
plt.title("Age Distribution")
plt.show()

# %%
#bar plot representation
data['Sex'].value_counts().plot(kind='bar')

# %%
data['Pclass'].value_counts().plot(kind='barh',color = 'red')

# %%
plt.bar(data['Survived'],data['Sex'])
plt.xlabel("Survived Rate")
plt.ylabel("Gender")
plt.title("Gender Survived Distribution")
plt.show()

# %%
data['Survived'].value_counts()

# %%
#549 / (549+342)
index = data['Survived'].value_counts().keys().tolist()
print(index)
labels = data['Survived'].value_counts().values.tolist()
print(labels)

# %%
#Pie Chart
plt.pie(x = labels,
        labels = ['Dead','Alive'],
       colors = ['red','gold'],
       autopct="%.1f%%",
       shadow=True)
plt.title("Survived Distribution")
plt.legend()
plt.show()

# %%
#Pie Chart
plt.pie(x = [577,314],
        labels = ['M','F'],
       colors = ['green','blue'],
       autopct="%.1f%%",
       shadow=True)
plt.title("Gender Distribution")
plt.legend()
plt.show()

# %%
#pairwise relationship --> scatterplot()
plt.scatter(x=data['Age'],
            y=data['Fare'])
plt.xlabel("Age")
plt.ylabel("Fare")
plt.title("Age vs Fare Distribution")
plt.show()

# %%
import plotly
#!pip install cufflinks

# %%
import plotly as py
import plotly.graph_objects as go #for interactive graphs

# %%
from plotly.offline import init_notebook_mode,iplot
init_notebook_mode(connected=True)

# %%
#Let's visualize 
trace = go.Histogram(x = data['Age'],
                     nbinsx=20,
                     marker={'color':'red'})
#layout define for the graph
layout = go.Layout(title="Age Distribution")
#we combine the trace with the layout to display the figure
fig = go.Figure(data=trace,layout = layout)
fig

# %%
print(index)
print(labels)

# %%
#Now we will display for PieChart
trace = go.Pie(labels=['Dead','Alive'],
               values=[549,342],
               )
layout = go.Layout(title = 'Survived Distribution')
fig = go.Figure(data=trace,layout=layout)
fig.show()

# %%
#Box plot and Scatter Plot
trace = go.Box(x=data['Pclass'],
               y=data['Age'],
               marker={'color':'blue'})
layout = go.Layout(title="Age vs Pclass Distribution")
fig = go.Figure(data=trace,layout = layout)
fig.show()

# %%
#Scatter Plot representation ---> Age vs Fare
trace = go.Scatter(x=data['Age'],y=data['Fare'],
                   mode='markers',
                   marker={'color':'violet'})
layout = go.Layout(
                   title="Age vs Fare Distribution")
fig = go.Figure(data=trace,layout=layout)
fig.show()

# %%
#Understanding the missing values and filling the missing values
data.isnull().sum()

# %%
print(data['Age'].mean())

# %%
#we can fill the Age column missing values with mean
data.Age = data['Age'] = data['Age'].fillna(data['Age'].mean(),inplace=True);
data.isnull().sum()

# %%
data['Embarked'] = data['Embarked'].fillna('S')

# %%
data['Age'] = data['Age'].fillna(data['Age'].mean());
data.isnull().sum()

# %%
data.drop(columns=['Cabin'],inplace=True)

# %%
data.isnull().sum()

# %%
data.head(10)

# %%
#Feature Engineering is a process of creating, transforming or extracting important information from the features before making the machine learning model ready
data.columns

# %%
pclass = pd.get_dummies(data['Pclass'],drop_first=True)
pclass
